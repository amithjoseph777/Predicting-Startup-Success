# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('CAX_Startup_Data.csv')
df.head()
# Out:
#   Company_Name Dependent-Company Status year of founding  \
# 0     Company1                  Success          No Info
# 1     Company2                  Success             2011
# 2     Company3                  Success             2011
# 3     Company4                  Success             2009
# 4     Company5                  Success             2010
#
#   Age of company in years  Internet Activity Score  \
# 0                 No Info                     -1.0
# 1                       3                    125.0
# 2                       3                    455.0
# 3                       5                    -99.0
# 4                       4                    496.0
#
#      Short Description of company profile  \
# 0                      Video distribution
# 1                                     NaN
# 2                Event Data Analytics API
# 3  The most advanced analytics for mobile
# 4   The Location-Based Marketing Platform
#
# ...

# %%
df.shape
# Out:
# (472, 116)

# %%
df.columns
# Out:
# Index(['Company_Name', 'Dependent-Company Status', 'year of founding',
#        'Age of company in years', 'Internet Activity Score',
#        'Short Description of company profile', 'Industry of company',
#        'Focus functions of company', 'Investors', 'Employee Count',
#        ...
#        'Percent_skill_Data Science', 'Percent_skill_Business Strategy',
#        'Percent_skill_Product Management', 'Percent_skill_Sales',
#        'Percent_skill_Domain', 'Percent_skill_Law', 'Percent_skill_Consulting',
#        'Percent_skill_Finance', 'Percent_skill_Investment', 'Renown score'],
#       dtype='object', length=116)

# %%
list(df.columns)
# Out:
# ['Company_Name',
#  'Dependent-Company Status',
#  'year of founding',
#  'Age of company in years',
#  'Internet Activity Score',
#  'Short Description of company profile',
#  'Industry of company',
#  'Focus functions of company',
#  'Investors',
#  'Employee Count',
#  'Employees count MoM change',
#  'Has the team size grown',
#  'Est. Founding Date',
#  'Last Funding Date',
#  'Last Funding Amount',
#  'Country of company',
#  'Continent of company',
#  'Number of Investors in Seed',
#  'Number of Investors in Angel and or VC',
#  'Number of Co-founders',
#  'Number of of advisors',
#  'Team size Senior leadership',
#  'Team size all employees',
#  'Presence of a top angel or venture fund in previous round of investment',
#  'Number of of repeat investors',
#  'Number of  Sales Support material',
#  'Worked in top companies',
#  'Average size of companies worked for in the past',
#  'Have been part of startups in the past?',
# ...

# %%
important_cols = [
    'Age of company in years',
    'Industry of company'
]

# %%
df = df.dropna(subset=['Industry of company'])

# %%
df.shape
# Out:
# (348, 116)

# %%
df = df.drop(["Gartner hype cycle stage"], axis = 1)

# %%
nas = pd.DataFrame(df.isna().sum()/df.shape[0])

# %%
nas = nas.reset_index(drop=False)

# %%
nas
# Out:
#                         index         0
# 0                Company_Name  0.000000
# 1    Dependent-Company Status  0.000000
# 2            year of founding  0.000000
# 3     Age of company in years  0.034483
# 4     Internet Activity Score  0.000000
# ..                        ...       ...
# 111         Percent_skill_Law  0.000000
# 112  Percent_skill_Consulting  0.000000
# 113     Percent_skill_Finance  0.000000
# 114  Percent_skill_Investment  0.000000
# 115              Renown score  0.000000
#
# [116 rows x 2 columns]

# %%
nas.columns
# Out:
# Index(['index', 0], dtype='object')

# %%
nas[nas[0] > 0.1]
# Out:
#                                          index         0
# 5         Short Description of company profile  0.198276
# 8                                    Investors  0.212644
# 9                               Employee Count  0.235632
# 10                  Employees count MoM change  0.339080
# 13                           Last Funding Date  0.160920
# 14                         Last Funding Amount  0.258621
# 61         Specialization of highest education  0.158046
# 91                 Industry trend in investing  0.123563
# 99                    Gartner hype cycle stage  0.318966
# 100  Time to maturity of technology (in years)  0.318966

# %%
df["Employees count MoM change"].value_counts()
# Out:
#  0.0      39
#  8.0       6
#  4.0       6
#  7.0       5
#  3.0       4
#  13.0      4
#  9.0       4
# -4.0       4
#  6.0       3
#  17.0      3
#  5.0       3
#  2.0       3
# -100.0     3
#  1.0       2
#  11.0      2
# -7.0       2
# -1.0       2
# -5.0       2
#  40.0      1
# -17.0      1
# -3.0       1
#  15.0      1
# -6.0       1
# -2.0       1
#  10.0      1
#  45.0      1
# -13.0      1
#  29.0      1
#  20.0      1
#  33.0      1
# Name: Employees count MoM change, dtype: int64

# %%
df["Employee Count"].value_counts()
# Out:
# 14.0     6
# 5.0      5
# 13.0     5
# 6.0      5
# 12.0     4
# 18.0     4
# 4.0      4
# 22.0     4
# 41.0     3
# 0.0      3
# 9.0      3
# 26.0     3
# 23.0     2
# 1.0      2
# 83.0     2
# 16.0     2
# 28.0     2
# 10.0     2
# 20.0     2
# 52.0     2
# 2.0      2
# 3.0      2
# 24.0     2
# 8.0      2
# 7.0      2
# 39.0     2
# 32.0     2
# 36.0     1
# 15.0     1
# 30.0     1
# 168.0    1
# 48.0     1
# 172.0    1
# 53.0     1
# 43.0     1
# 21.0     1
# 410.0    1
# 95.0     1
# 67.0     1
# 31.0     1
# 37.0     1
# 103.0    1
# 55.0     1
# 19.0     1
# 79.0     1
# 118.0    1
# 73.0     1
# 178.0    1
# 138.0    1
# 45.0     1
# 11.0     1
# 50.0     1
# 115.0    1
# 129.0    1
# 47.0     1
# 34.0     1
# 71.0     1
# Name: Employee Count, dtype: int64

# %%
df[["Time to maturity of technology (in years)"]].value_counts()
# Out:
# Time to maturity of technology (in years)
# 2 to 5                                       76
# 0 to 2                                       21
# 5 to 10                                      12
# dtype: int64

# %%
max(df["Employee Count"])
# Out:
# 410.0

# %%
df = df.dropna()

# %%
df.shape
# Out:
# (109, 115)

# %%
all_rows_no_info = []
for col in df.columns:
    rows_no_info = list(df[df[col]=='No Info'].index)
    print(col)
    print(rows_no_info)
    all_rows_no_info.extend(rows_no_info)
# Out:
# Company_Name
# []
# Dependent-Company Status
# []
# year of founding
# []
# Age of company in years
# []
# Internet Activity Score
# []
# Short Description of company profile
# []
# Industry of company
# []
# Focus functions of company
# []
# Investors
# []
# Employee Count
# []
# Employees count MoM change
# []
# Has the team size grown
# []
# Est. Founding Date
# []
# Last Funding Date
# []
# Last Funding Amount
# []
# Country of company
# []
# Continent of company
# []
# Number of Investors in Seed
# [33]
# Number of Investors in Angel and or VC
# [33]
# Number of Co-founders
# []
# Number of of advisors
# []
# Team size Senior leadership
# []
# Team size all employees
# [313, 335]
# Presence of a top angel or venture fund in previous round of investment
# [37, 38, 78, 82, 89, 104, 146, 273, 313, 327, 331, 335]
# Number of of repeat investors
# []
# Number of  Sales Support material
# []
# Worked in top companies
# []
# Average size of companies worked for in the past
# ...

# %%
len(list(set(all_rows_no_info)))
# Out:
# 93

# %%
df[['google page rank of company website']]
# Out:
#     google page rank of company website
# 2                                 71391
# 3                                 11847
# 5                                591816
# 8                                256921
# 10                               142907
# ..                                  ...
# 381                              480111
# 382                              899614
# 383                               69882
# 387                               37120
# 388                              161711
#
# [109 rows x 1 columns]

# %%
all_rows_no_info
# Out:
# [Int64Index([], dtype='int64'),
#  Int64Index([], dtype='int64'),
#  Int64Index([], dtype='int64'),
#  Int64Index([], dtype='int64'),
#  Int64Index([], dtype='int64'),
#  Int64Index([], dtype='int64'),
#  Int64Index([], dtype='int64'),
#  Int64Index([], dtype='int64'),
#  Int64Index([], dtype='int64'),
#  Int64Index([], dtype='int64'),
#  Int64Index([], dtype='int64'),
#  Int64Index([], dtype='int64'),
#  Int64Index([], dtype='int64'),
#  Int64Index([], dtype='int64'),
#  Int64Index([], dtype='int64'),
#  Int64Index([], dtype='int64'),
#  Int64Index([], dtype='int64'),
#  Int64Index([33], dtype='int64'),
#  Int64Index([33], dtype='int64'),
#  Int64Index([], dtype='int64'),
#  Int64Index([], dtype='int64'),
#  Int64Index([], dtype='int64'),
#  Int64Index([313, 335], dtype='int64'),
#  Int64Index([37, 38, 78, 82, 89, 104, 146, 273, 313, 327, 331, 335], dtype='int64'),
#  Int64Index([], dtype='int64'),
#  Int64Index([], dtype='int64'),
#  Int64Index([], dtype='int64'),
# ...

# %%
df[df['Number of Investors in Seed']=='No Info']
# Out:
#    Company_Name Dependent-Company Status year of founding  \
# 33    Company34                  Success             2011
#
#    Age of company in years  Internet Activity Score  \
# 33                       3                     68.0
#
#    Short Description of company profile Industry of company  \
# 33          Social Media ROI Measurment         Advertising
#
#    Focus functions of company                           Investors  \
# 33  Social Media optimization  Vaidya Capital Partners|[212]Media
#
#     Employee Count  ...  Percent_skill_Data Science  \
# 33             9.0  ...                           0
#
#    Percent_skill_Business Strategy Percent_skill_Product Management  \
# 33                               0                                0
#
#    Percent_skill_Sales  Percent_skill_Domain Percent_skill_Law  \
# 33                   0                     0                 0
#
#    Percent_skill_Consulting Percent_skill_Finance Percent_skill_Investment  \
# ...
